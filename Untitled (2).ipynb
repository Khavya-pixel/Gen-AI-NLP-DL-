# %%
# !pip install openai==0.28.0

# %%
import sys
print(sys.version)

import openai
print(openai.__version__)
# Out:
# 3.11.15 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:12:15) [MSC v.1942 64 bit (AMD64)]
# 2.40.0

# %%
# !conda create -n py311 python=3.11 -y
# !conda run -n py311 pip install ipykernel openai==0.28.0
# !conda run -n py311 python -m ipykernel install --user --name py311 --display-name "Python 3.11"

# %%
import sys
import openai

print(sys.version)
print(openai.__version__)
# Out:
# 3.11.15 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:12:15) [MSC v.1942 64 bit (AMD64)]
# 2.40.0

# %%
pip install --upgrade openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI

client = OpenAI(api_key="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")

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user",
         "content": "Give me 3 ideas for apps I could build with OpenAI APIs"}
    ]
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 5
#       1 from openai import OpenAI
#       2
#       3 client = OpenAI(api_key="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")
#       4
# ----> 5 response = client.chat.completions.create(
#       6     model="gpt-4o-mini",
#       7     messages=[
#       8         {"role": "user",
#
# File ~\anaconda3\envs\py311\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...
