# %%
from google import genai

# %%
client = genai.Client(api_key="AQ.Ab8RN6L2ebaIjbAqbmvTfEHkmNAwnSdwpKNvzOs_wf9SwNGbmA")

response = client.models.generate_content(
    model="models/gemini-2.5-flash",
    contents="Give me 3 ideas for apps I could build with Google AI APIs"
)

print(response.text)
# Out:
# Google AI APIs offer a powerful suite of tools to build intelligent and innovative applications. Here are 3 app ideas, leveraging different aspects of their capabilities:
#
# ---
#
# ### 1. **AI Dietary Scanner & Allergen Identifier**
#
# **Concept:** An app that helps users quickly check food products for allergens, dietary restrictions (vegan, gluten-free, etc.), or even nutritional information by simply scanning a label.
#
# **How it uses Google AI:**
#
# *   **Vision AI (OCR):** When the user takes a photo of a food label, Vision AI's Optical Character Recognition (OCR) capability will extract all the text from the image – specifically the ingredient list and nutritional facts.
# *   **Gemini (Natural Language Understanding & Reasoning):** The extracted text (ingredient list) is fed into Gemini. The user would have pre-set their dietary preferences and allergies within the app (e.g., "allergic to peanuts," "lactose intolerant," "vegan"). Gemini then processes the ingredient list, compares it against the user's profile, and provides a clear "safe/unsafe" verdict along with detailed explanations of why an item is flagged (e.g., "Contains whey protein, which is dairy-derived").
# *   **Potential Enhancement:** Gemini could also suggest alternative products or recipes if an item is flagged, or even explain complex scientific-sounding ingredients in simpler terms.
#
# **Why it's useful:** Saves time and anxiety for people with allergies, specific diets, or those trying to make healthier choices while shopping.
#
# ---
#
# ### 2. **Personalized Learning Co-pilot**
#
# **Concept:** A smart study assistant that can transform raw study materials (notes, textbook pages, lecture recordings) into personalized learning experiences like summaries, flashcards, and practice questions.
#
# **How it uses Google AI:**
#
# *   **Speech-to-Text API:** Users can record their lectures or study sessions. Speech-to-Text will accurately transcribe the audio into text.
# *   **Vision AI (OCR):** Users can take photos of textbook pages or handwritten notes, and OCR will convert them into digital text.
# *   **Gemini (Multimodal Understanding & Generation):**
#     *   Once the input (text from transcription or OCR) is processed, Gemini will analyze the content.
#     *   It can generate concise summaries of chapters or lectures.
#     *   It can identify key concepts and automatically create digital flashcards for review.
#     *   It can generate practice questions (multiple choice, true/false, short answer) based on the material, complete with explanations for correct and incorrect answers.
#     *   It could even generate mnemonic devices or analogies to help the user understand complex topics.
#
# **Why it's useful:** Enhances study efficiency, provides tailored learning tools, and helps students better comprehend and retain information from various sources.
#
# ---
#
# ### 3. **AI Meeting Co-pilot & Action Item Extractor**
#
# **Concept:** An intelligent app that records meetings, provides real-time transcription, summarizes key discussions, and automatically identifies and tracks action items and decisions made during the meeting.
#
# **How it uses Google AI:**
#
# *   **Speech-to-Text API:** Records and transcribes spoken dialogue from the meeting in real-time or from an uploaded audio file. With speaker diarization (if supported/configured), it could even identify different speakers.
# *   **Natural Language API:** Analyzes the transcribed text to understand the content. It can identify key entities (people, organizations, dates), assess sentiment (e.g., if there's disagreement), and categorize topics discussed.
# *   **Gemini (Summarization & Action Extraction):**
#     *   Takes the transcribed and analyzed text.
#     *   Generates a concise summary of the entire meeting, highlighting critical points and decisions.
#     *   Automatically identifies phrases and contexts that indicate action items ("John will follow up on X," "We need to schedule Y," "Decision: Z will be implemented").
#     *   Extracts these action items, assigns them (if speakers are identified), and suggests due dates based on context.
#     *   Can also generate a clean, formatted meeting minutes document.
#
# **Why it's useful:** Saves time spent on note-taking, ensures no action items are missed, improves accountability, and provides a searchable record of meeting discussions and decisions.

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6L2ebaIjbAqbmvTfEHkmNAwnSdwpKNvzOs_wf9SwNGbmA")

models = client.models.list()

for m in models:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
